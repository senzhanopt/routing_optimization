# %%
from routing_optimization.main import plan_route_from_file
from routing_optimization.utils import visualize_route
from pathlib import Path

# %%
data_file = Path().resolve().parent / "data" / "case1.json"
result = plan_route_from_file(data_file)
print(f"Total Distance: {result['total_distance']:.2f}\n")
print("Route IDs:")
print(" -> ".join(result['route_ids']))
visualize_route(result["route"])
# Out:
# Total Distance: 14.09
#
# Route IDs:
# Depot -> D0 -> P0 -> D1 -> Depot

# %%
data_file = Path().resolve().parent / "data" / "case2.json"
result = plan_route_from_file(data_file)
print(f"Total Distance: {result['total_distance']:.2f}\n")
print("Route IDs:")
print(" -> ".join(result['route_ids']))
visualize_route(result["route"])
# Out:
# Total Distance: 39.04
#
# Route IDs:
# Depot -> D19 -> D9 -> D12 -> D5 -> D16 -> D8 -> P0 -> D17 -> D6 -> D3 -> D14 -> D7 -> D13 -> D18 -> D1 -> D10 -> D0 -> Depot

# %%
data_file = Path().resolve().parent / "data" / "case3.json"
result = plan_route_from_file(data_file)
print(f"Total Distance: {result['total_distance']:.2f}\n")
print("Route IDs:")
print(" -> ".join(result['route_ids']))
visualize_route(result["route"])
# Out:
# Total Distance: 756.11
#
# Route IDs:
# Depot -> D9 -> D107 -> D0 -> D173 -> D134 -> D148 -> D71 -> D146 -> D89 -> D29 -> D2 -> D161 -> D94 -> D13 -> D35 -> D58 -> D191 -> D67 -> D16 -> D139 -> D5 -> D62 -> D31 -> D80 -> D115 -> D164 -> D182 -> D49 -> D76 -> D106 -> D128 -> D124 -> D101 -> D133 -> D26 -> D143 -> D7 -> D85 -> D79 -> D56 -> D74 -> D44 -> D92 -> D151 -> D103 -> D52 -> D169 -> D97 -> D61 -> D83 -> D34 -> D70 -> D160 -> D178 -> D20 -> D88 -> D187 -> D38 -> D142 -> D116 -> D65 -> D25 -> D130 -> D11 -> D152 -> D125 -> D47 -> D17 -> D112 -> D119 -> D155 -> D196 -> D53 -> D121 -> D98 -> D40 -> D22 -> D43 -> D137 -> D110 -> D157 -> P4 -> Depot
